# %% [markdown]
# <a href="https://colab.research.google.com/github/shresthasusan/lab/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("/content/drive/MyDrive/Colab Notebooks/nepse.csv")
df.head(100)
# Out:
#      SN      Contract No.  Buyer  Seller  Quantity   Rate      Amount
# 0     1  2024012501000096     33      58        10  456.0    4,560.00
# 1     2  2024012501000098     33      17        10  456.0    4,560.00
# 2     3  2024012501000106     72      34        10  457.0    4,570.00
# 3     4  2024012501000107     72      58        10  457.0    4,570.00
# 4     5  2024012501000121     72      44        10  457.4    4,574.00
# ..  ...               ...    ...     ...       ...    ...         ...
# 95   96  2024012501002475     29      45        10  457.1    4,571.00
# 96   97  2024012501002517     29      34        10  457.1    4,571.00
# 97   98  2024012501002528     29      38        10  457.1    4,571.00
# 98   99  2024012501002542     29      44        10  457.1    4,571.00
# 99  100  2024012501002565     29      50       430  457.1  196,553.00
#
# [100 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot for unique buyers and their quantities
buyer_total_quantity = df.groupby('Buyer')['Quantity'].sum().reset_index()

plt.figure(figsize=(15, 8))
sns.barplot(data=buyer_total_quantity, x='Buyer', y='Quantity')
plt.title('Total Quantity per Buyer')
# Out:
# Text(0.5, 1.0, 'Total Quantity per Buyer')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the total quantity for each unique buyer
buyer_total_quantity = df.groupby('Buyer')['Quantity'].sum().reset_index()

# Plot a pie chart
plt.figure(figsize=(15, 15))
plt.pie(buyer_total_quantity['Quantity'], labels=buyer_total_quantity['Buyer'], autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Total Quantity by Buyer')
# Out:
# Text(0.5, 1.0, 'Percentage of Total Quantity by Buyer')

# %%
# # Create a histogram for the quantities within the specified price range
# price_range_df = df[(df['Rate'] >= 440) & (df['Rate'] <= 470)]

# Create a histogram
plt.figure(figsize=(10, 6))  # Set the size of the plot
bin_edges = [i for i in range(451, 462, 5)]
plt.hist(price_range_df['Rate'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Prices in the Range [451, 461]')
plt.xlabel('Rate')
plt.ylabel('Frequency')
plt.show()

# %%
bin_edges = [i for i in range(451, 462, 1)]  # Adjust the step size if needed

# Create a histogram with specified bin edges
plt.figure(figsize=(10, 6))
plt.hist(df['Rate'], bins=bin_edges, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Prices')
plt.xlabel('Price')
plt.ylabel('Quantity')
plt.xticks(bin_edges)  # Set x-axis ticks to the specified bin edges
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
bin_edges = [i for i in range(451, 462, 1)]  # Adjust the step size if needed

# Create a histogram with 'Rate' and use 'Quantity' for frequency
plt.figure(figsize=(10, 6))
plt.hist(df['Rate'], bins=bin_edges, weights=df['Quantity'], color='skyblue', edgecolor='black')
plt.title('Histogram of Rate and Quantity')
plt.xlabel('Rate')
plt.ylabel('Quantity')
plt.xticks(bin_edges)  # Set x-axis ticks to the specified bin edges
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Find the maximum quantity bought by each buyer
max_quantity_by_buyer = df.groupby('Buyer')['Quantity'].max().reset_index()

# Display the resulting DataFrame
print(max_quantity_by_buyer)
# Out:
#     Buyer  Quantity
# 0       1       500
# 1       4        10
# 2       5        11
# 3       6        20
# 4       7        10
# 5       8       299
# 6      11        10
# 7      13       452
# 8      14        10
# 9      16        34
# 10     17        30
# 11     19       300
# 12     21       803
# 13     22       290
# 14     25        10
# 15     29       430
# 16     33       420
# 17     34       450
# 18     35       190
# 19     36        60
# 20     38       200
# 21     39        10
# 22     40        10
# 23     41       100
# 24     42       342
# 25     44        40
# 26     45        40
# 27     46        50
# 28     47        40
# 29     48       100
# 30     49        20
# 31     50        10
# 32     52        10
# 33     53        20
# 34     54        10
# 35     56        10
# 36     57       100
# 37     58        50
# 38     59       290
# 39     60        10
# 40     65        70
# 41     72        10

# %%
# Find the maximum quantity bought by any buyer
max_quantity = df['Quantity'].max()

# Find the row(s) with the greatest maximum quantity
greatest_max_quantity = df[df['Quantity'] == max_quantity][['Buyer', 'Quantity']]

# Display the resulting DataFrame
print(greatest_max_quantity)
# Out:
#      Buyer  Quantity
# 704     21       803

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Rate', color='skyblue')
plt.title('Box Plot of Rate')
plt.xlabel('Rate')
# Out:
# Text(0.5, 0, 'Rate')
